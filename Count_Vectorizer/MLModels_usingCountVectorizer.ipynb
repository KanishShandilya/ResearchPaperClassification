# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import hstack
from sklearn import metrics
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB,GaussianNB,BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC,SVC
import pickle
from sklearn.ensemble import RandomForestClassifier

# %%
X_train=pd.read_csv("../dataset/X_train.csv")
X_test=pd.read_csv("../dataset/X_test.csv")
y_train=pd.read_csv("../dataset/y_train.csv")
y_test=pd.read_csv("../dataset/y_test.csv")

# %%
X_test.shape
# Out:
# (4195, 2)

# %%
X_train_title=X_train['TITLE']
X_train_abstract=X_train['ABSTRACT']

# %%
cv_title=CountVectorizer()

# %%
title_feature=cv_title.fit_transform(X_train_title)

# %%
print(len(cv_title.vocabulary_))
print(cv_title.vocabulary_)
# Out:
# 12505
# {'number': 7727, 'rich': 9468, 'word': 12230, 'partial': 8117, 'invers': 5522, 'problem': 8735, 'sturm': 10682, 'liouvil': 6194, 'oper': 7863, 'graph': 4593, 'loop': 6277, 'mind': 6920, 'gap': 4357, 'well': 12136, 'log': 6250, 'data': 2747, 'analysi': 684, 'hyper': 5101, 'suprim': 10887, 'cam': 1712, 'softwar': 10308, 'pipelin': 8417, 'electr': 3446, 'transient': 11394, 'law': 6019, 'neuron': 7496, 'microdomain': 6833, 'base': 1163, 'electro': 3449, 'diffus': 3059, 'evolutionari': 3737, 'central': 1882, 'maxim': 6635, 'cliqu': 2101, 'mobil': 7008, 'social': 10293, 'network': 7481, 'cyclic': 2699, 'weight': 12127, 'ellp': 3492, 'space': 10353, 'coupl': 2525, 'ident': 5195, 'local': 6237, 'fermion': 3978, 'chain': 1928, 'quasi': 8986, 'random': 9084, 'disord': 3140, 'densiti': 2928, 'repres': 9344, 'diagon': 3012, 'form': 4166, 'larg': 5986, 'degre': 2874, 'geodet': 4439, 'hull': 5066, 'hard': 4747, 'chordal': 2023, 'fast': 3891, 'autom': 1021, 'strong': 10667, 'gravit': 4618, 'lens': 6097, 'convolut': 2433, 'neural': 7484, 'homogen': 4992, 'nonlinear': 7638, 'ellipt': 3491, 'system': 10971, 'nonreflex': 7656, 'musielak': 7289, 'orlicz': 7919, 'critic': 2580, 'expon': 3808, 'geode': 4438, 'current': 2668, 'activ': 423, 'hypothesi': 5155, 'test': 11129, 'beyond': 1266, 'chernoff': 1991, 'stein': 10580, 'uncov': 11647, 'offshor': 7797, 'financi': 4032, 'center': 1880, 'conduit': 2333, 'sink': 10148, 'global': 4520, 'corpor': 2478, 'ownership': 8000, 'univers': 11706, 'thin': 11202, 'film': 4027, 'model': 7017, 'ginzburg': 4494, 'landau': 5964, 'energi': 3561, 'dipolar': 3089, 'interact': 5449, 'measur': 6669, 'quantifi': 8974, 'perform': 8241, 'error': 3665, 'rate': 9112, 'surrog': 10902, 'loss': 6291, 'exampl': 3746, 'ssl': 10506, 'decompos': 2814, 'manifold': 6484, 'cartesian': 1792, 'product': 8743, 'complex': 2291, 'surnam': 10899, 'comparison': 2276, 'brazil': 1552, 'portug': 8585, 'radio': 9052, 'inerti': 5344, 'track': 11352, 'ble': 1417, 'beacon': 1192, 'prior': 8716, 'map': 6498, 'util': 11792, 'lexic': 6123, 'similar': 10120, 'relat': 9288, 'low': 6302, 'resourc': 9380, 'languag': 5974, 'pivot': 8424, 'smt': 10262, 'banglalekha': 1141, 'isol': 5581, 'comprehens': 2302, 'bangla': 1139, 'handwritten': 4739, 'charact': 1950, 'dataset': 2753, 'teleconnect': 11083, 'structur': 10673, 'el': 3434, 'niño': 7570, 'southern': 10348, 'oscil': 7929, 'volcan': 11993, 'erupt': 3666, 'evolv': 3739, 'perspect': 8272, 'deep': 2829, 'learnt': 6054, 'classif': 2081, 'light': 6158, 'curv': 2671, 'optim': 7882, 'quantum': 8981, 'reinforc': 9276, 'algorithm': 585, 'effici': 3395, 'asp': 908, 'encod': 3543, 'sequenti': 9965, 'pattern': 8151, 'mine': 6923, 'task': 11041, 'deform': 2868, 'condit': 2329, 'pseudorepresent': 8844, 'probabilist': 8731, 'causal': 1831, 'influenc': 5369, 'stochast': 10613, 'develop': 2986, 'regress': 9261, 'non': 7599, 'linear': 6176, 'advanc': 482, 'steel': 10570, 'microstructur': 6877, 'learn': 6050, 'method': 6778, 'asai': 896, 'cube': 2644, 'function': 4286, 'langland': 5973, 'conjectur': 2357, 'comput': 2309, 'life': 6145, 'expect': 3789, 'incomplet': 5307, 'binari': 1334, 'vote': 12010, 'deleg': 2887, 'proxi': 8817, 'liquid': 6200, 'democraci': 2908, 'special': 10391, 'polar': 8503, 'characterist': 1953, 'featur': 3935, 'three': 11217, 'dimension': 3079, 'terahertz': 11113, 'photon': 8360, 'crystal': 2615, 'silicon': 10110, 'diamond': 3023, 'logic': 6253, 'gate': 4372, 'trap': 11415, 'ion': 5536, 'qubit': 9006, 'finit': 4037, 'time': 11252, 'distribut': 3166, 'equat': 3628, 'solver': 10329, 'minimum': 6935, 'l1': 5908, 'norm': 7675, 'solut': 10324, 'snect': 10272, 'scalabl': 9733, 'constrain': 2389, 'tucker': 11516, 'decomposit': 2815, 'integr': 5439, 'multi': 7170, 'platform': 8452, 'associahedra': 924, 'δntexteff': 12486, 'entropi': 3592, 'earli': 3345, 'decay': 2800, 'gravitino': 4620, 'doubl': 3225, 'threshold': 11219, 'digraph': 3066, 'thermoregul': 11192, 'mouse': 7131, 'rat': 9110, 'human': 5067, 'insight ...

# %%
print(title_feature.shape)
# Out:
# (16777, 12505)

# %%
title_feature_test=cv_title.transform(X_test['TITLE'])

# %%
cv_abstract=CountVectorizer(ngram_range=(1,3),min_df=4)
abstract_feature=cv_abstract.fit_transform(X_train_abstract)

# %%
print(len(cv_abstract.vocabulary_))
print(cv_abstract.vocabulary_)
# Out:
# 72501
, 'suprim': 63679, 'cam': 7935, 'instrument': 31377, 'hsc': 29094, 'prototyp': 51155, 'larg': 33315, 'synopt': 63948, 'survey': 63780, 'manag': 36346, 'system': 63996, 'ad': 1362, 'custom': 13749, 'scale': 56215, 'capabl': 8013, 'novel': 42624, 'sinc': 59287, 'lsst': 35803, 'codebas': 9893, 'design': 15794, 'primarili': 49212, 'reduc': 53320, 'strateg': 62191, 'program': 50279, 'also': 2783, 'recommend': 53181, 'observ': 43274, 'includ': 30251, 'high': 28441, 'level': 34433, 'step': 61952, 'scienc': 56566, 'readi': 52833, 'catalog': 8393, 'low': 35629, 'detrend': 16257, 'character': 8907, 'optic imag': 44517, 'imag data': 29618, 'data process': 14210, 'process pipelin': 50101, 'subaru ...

# %%
print(abstract_feature.shape)
# Out:
# (16777, 72501)

# %%
abstract_feature_test=cv_abstract.transform(X_test['ABSTRACT'])

# %%
print(abstract_feature_test.shape)
# Out:
# (4195, 72501)

# %%
print(title_feature_test.shape)
# Out:
# (4195, 12505)

# %%
X_train_final=hstack((title_feature,abstract_feature))
X_test_final=hstack((title_feature_test,abstract_feature_test))

# %%
y_train=y_train.values

# %%
y_train.shape
# Out:
# (16777, 6)

# %%
y_test=y_test.values

# %%
y_test.shape
# Out:
# (4195, 6)

# %% [markdown]
# ## naive Bayes

# %%
classifier = OneVsRestClassifier(MultinomialNB())
classifier.fit(X_train_final, y_train)
predictions = classifier.predict (X_test_final)


print("Accuracy :",metrics.accuracy_score(y_test, predictions))
print("Hamming loss ",metrics.hamming_loss(y_test,predictions))


precision = metrics.precision_score(y_test, predictions, average='micro')
recall = metrics.recall_score(y_test, predictions, average='micro')
f1 = metrics.f1_score(y_test, predictions, average='micro')
 
print("Micro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

precision = metrics.precision_score(y_test, predictions, average='macro')
recall = metrics.recall_score(y_test, predictions, average='macro')
f1 = metrics.f1_score(y_test, predictions, average='macro')
 
print("Macro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))
# Out:
# Accuracy : 0.6188319427890345
# Hamming loss  0.08247914183551848
# Micro-average quality numbers
# Precision: 0.7655, Recall: 0.8721, F1-measure: 0.8153
# Macro-average quality numbers
# Precision: 0.7866, Recall: 0.6472, F1-measure: 0.6322

# %%
nb_classifier = OneVsRestClassifier(BernoulliNB())
nb_classifier.fit(X_train_final, y_train)
predictions = nb_classifier.predict (X_test_final)


print("Accuracy :",metrics.accuracy_score(y_test, predictions))
print("Hamming loss ",metrics.hamming_loss(y_test,predictions))


precision = metrics.precision_score(y_test, predictions, average='micro')
recall = metrics.recall_score(y_test, predictions, average='micro')
f1 = metrics.f1_score(y_test, predictions, average='micro')
 
print("Micro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

precision = metrics.precision_score(y_test, predictions, average='macro')
recall = metrics.recall_score(y_test, predictions, average='macro')
f1 = metrics.f1_score(y_test, predictions, average='macro')
 
print("Macro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))
# Out:
# Accuracy : 0.6071513706793802
# Hamming loss  0.0867699642431466
# Micro-average quality numbers
# Precision: 0.7709, Recall: 0.8314, F1-measure: 0.8000
# Macro-average quality numbers
# Precision: 0.5177, Recall: 0.5719, F1-measure: 0.5410
# C:\Users\kanis\anaconda3\envs\toxic_comment_project\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Logistic regression

# %%
lr_classifier = OneVsRestClassifier(LogisticRegression(max_iter=500,class_weight='balanced'))
lr_classifier.fit(X_train_final, y_train)
predictions = lr_classifier.predict (X_test_final)


print("Accuracy :",metrics.accuracy_score(y_test, predictions))
print("Hamming loss ",metrics.hamming_loss(y_test,predictions))


precision = metrics.precision_score(y_test, predictions, average='micro')
recall = metrics.recall_score(y_test, predictions, average='micro')
f1 = metrics.f1_score(y_test, predictions, average='micro')
 
print("Micro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

precision = metrics.precision_score(y_test, predictions, average='macro')
recall = metrics.recall_score(y_test, predictions, average='macro')
f1 = metrics.f1_score(y_test, predictions, average='macro')
 
print("Macro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))
# Out:
# Accuracy : 0.6405244338498212
# Hamming loss  0.07957886372665872
# Micro-average quality numbers
# Precision: 0.8061, Recall: 0.8148, F1-measure: 0.8104
# Macro-average quality numbers
# Precision: 0.7286, Recall: 0.7159, F1-measure: 0.7214

# %% [markdown]
# ## SVM

# %%
svm_classifier = OneVsRestClassifier(LinearSVC())
svm_classifier.fit(X_train_final, y_train)
predictions = svm_classifier.predict (X_test_final)


print("Accuracy :",metrics.accuracy_score(y_test, predictions))
print("Hamming loss ",metrics.hamming_loss(y_test,predictions))


precision = metrics.precision_score(y_test, predictions, average='micro')
recall = metrics.recall_score(y_test, predictions, average='micro')
f1 = metrics.f1_score(y_test, predictions, average='micro')
 
print("Micro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

precision = metrics.precision_score(y_test, predictions, average='macro')
recall = metrics.recall_score(y_test, predictions, average='macro')
f1 = metrics.f1_score(y_test, predictions, average='macro')
 
print("Macro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))
# Out:
# Accuracy : 0.6240762812872467
# Hamming loss  0.08398887564560985
# Micro-average quality numbers
# Precision: 0.8102, Recall: 0.7805, F1-measure: 0.7951
# Macro-average quality numbers
# Precision: 0.7510, Recall: 0.6598, F1-measure: 0.6960

# %%
svm_classifier = OneVsRestClassifier(RandomForestClassifier(class_weight='balanced'))
svm_classifier.fit(X_train_final, y_train)
predictions = svm_classifier.predict (X_test_final)


print("Accuracy :",metrics.accuracy_score(y_test, predictions))
print("Hamming loss ",metrics.hamming_loss(y_test,predictions))


precision = metrics.precision_score(y_test, predictions, average='micro')
recall = metrics.recall_score(y_test, predictions, average='micro')
f1 = metrics.f1_score(y_test, predictions, average='micro')
 
print("Micro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

precision = metrics.precision_score(y_test, predictions, average='macro')
recall = metrics.recall_score(y_test, predictions, average='macro')
f1 = metrics.f1_score(y_test, predictions, average='macro')
 
print("Macro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))
# Out:
# Accuracy : 0.6131108462455304
# Hamming loss  0.08585617798967024
# Micro-average quality numbers
# Precision: 0.8328, Recall: 0.7366, F1-measure: 0.7817
# Macro-average quality numbers
# Precision: 0.5643, Recall: 0.4963, F1-measure: 0.5251
# C:\Users\kanis\anaconda3\envs\toxic_comment_project\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Best model out of all three is Logistic Regression

# %%
with open('../models/count_vectorizer_lr.pkl', 'wb') as fid:
    pickle.dump(lr_classifier, fid)

# %% [markdown]
# ## saved the model
